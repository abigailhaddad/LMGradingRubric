# %% [markdown]
# # Automated LLM Evaluation
#
# This notebook provides an automated evaluation framework for Large Language Models (LLMs) using a set of predefined prompts and rubrics. The responses from the models are classified based on the rubrics, and the results are visualized in a styled DataFrame.
#
# ## Requirements
#
# - **Python Packages**: `enum`, `marvin`, `os`, `openai`, `pandas`, `pydantic`, `litellm`, `groq`; see requirements.txt file
# - **API Keys**: You need API keys for each of the LLM providers you intend to use. These keys should be stored as environment variables in the format `PROVIDER_KEY`. For example, for OpenAI, you would set an environment variable `OPENAI_KEY` with your API key.
#
# ## Workflow
#
# 1. **Set Up Configuration**: Initialize settings for Marvin and Pandas display options.
# 2. **Define Prompts and Rubrics**: Create a list of prompts and their corresponding rubrics for classification.
# 3. **Process Responses**: For each prompt, call the LLMs, retrieve responses, and classify them based on the rubrics.
# 4. **Visualize Results**: Pivot the DataFrame to have prompts as rows and models as columns, and apply styling to visualize the classification results.
#
# ## Outputs
#
# - `final_df`: A DataFrame containing the model, prompt, response, and classification category for each prompt-model pair.
# - `styled_df`: A styled DataFrame with prompts as rows, models as columns, and cells colored based on the classification category (PASS, FAIL, ERROR).
#
# ## Usage
#
# To use this framework, you will need to:
#
# 1. Set your API keys as environment variables.
# 2. Define your prompts and rubrics in the `prompt_rubric_pairs` list.
# 3. Run the notebook to generate and visualize the classification results.
#
# ## Customization
#
# You can customize this framework by:
#
# - Adding or modifying prompts and rubrics in the `prompt_rubric_pairs` list.
# - Adjusting the styling in the `colorize` function and `styled_df` creation to fit your preferences.
# - Changing the LLM providers and models in the `providers_models` dictionary.
#
# ## Notes
#
# - Ensure that your API keys are correctly set up and have the necessary permissions for accessing the LLMs.
# - The classification results are dependent on the rubrics defined and the responses from the LLMs.

# %%
from enum import Enum
import marvin
import os
import openai
import pandas as pd
from pydantic import BaseModel
import litellm
from groq import Groq
import numpy as np


marvin.settings.llm_temperature=0.0 # you want a grading schema which consistently gets you the same answers!!! 
marvin.settings.llm_max_tokens=200
llm_max_context_tokens=600 
openai.api_key = os.environ.get("OPENAI_KEY")  # this is for marvin, not litellm
marvin.settings.llm_model='openai/gpt-4'
pd.set_option('display.max_colwidth', None)

def create_response_df(providers_models: dict, prompts: list, n: int):
    """Generates a DataFrame from model responses for given prompts, repeated n times, more Pythonically."""
    responses = [
        {"model": model, "prompt": prompt, "response": get_model_response(model, prompt, provider)}
        for _ in range(n)
        for provider, models in providers_models.items()
        for model in models
        for prompt in prompts
    ]
    return pd.DataFrame(responses)
    
def calculate_proportions(df):
    """Calculates the proportion of 'PASS' responses for each prompt/model combination, ignoring 'ERROR' responses."""
    def proportion_pass(x):
        valid_responses = x[x != 'ERROR']
        if len(valid_responses) == 0:
            return 'ERROR'
        return np.mean(valid_responses == 'PASS')

    grouped = df.groupby(['prompt', 'model'])
    proportions = grouped['category'].apply(proportion_pass)
    return proportions.unstack()

def gradient_color(proportion):
    """Maps a proportion to a color gradient between green and red, or returns grey for 'ERROR'."""
    if proportion == 'ERROR':
        return 'background-color: grey'
    green_component = int(255 * proportion)
    red_component = 255 - green_component
    return f'background-color: rgb({red_component}, {green_component}, 0)'

    
def call_model(model: str, message: dict, temperature: float, api_key: str):
    """Calls the specified model with given parameters."""
    try:
        response = litellm.completion(model=model, messages=[message], temperature=temperature, api_key=api_key)
        return response
    except Exception as e:
        print(f"Error calling model: {e}")
        return None


def get_model_response(model, prompt, provider):
    """Helper function to clean up response retrieval and formatting."""
    response = call_model(model=model, message={"role": "user", "content": prompt}, temperature=0.0,
                          api_key=os.environ.get(f"{provider.upper()}_KEY"))
    return response["choices"][0]["message"]["content"].replace('\n', ', ').strip() if response else "Error or no response"

def classify_responses(df, prompt_rubric_pairs):
    """Efficiently classifies responses in the DataFrame using the rubrics, based on prompts."""
    prompt_to_rubric = {pair["prompt"]: pair["rubric"] for pair in prompt_rubric_pairs}

    def apply_rubric(row):
        rubric = prompt_to_rubric.get(row['prompt'])
        if rubric:
            return marvin.classify(row['response'], rubric).name
        return "ERROR"

    df['category'] = df.apply(apply_rubric, axis=1)
    return df

@marvin.classifier
class NumberofRs(Enum):
    PASS = """Says that the letter r is in the word carryforward four times"""
    FAIL = """Says something else, including that the letter r is in the word carryforward some number of times that is not four"""

@marvin.classifier
class TimeDiff(Enum):
    PASS = """Says that the time in Copenhagen is 6 PM"""
    FAIL = """Says something else"""
    
@marvin.classifier
class LetterLoc(Enum):
    PASS = """Says that 'y' is the letter"""
    FAIL = """Says something else"""

@marvin.classifier
class WeightQuestion(Enum):
    PASS = """Says that the feathers are heavier. Does not at any point say they weigh the same amount"""
    FAIL = """Says that the bricks and feathers are the same weight, that the bricks are heavier, or is ambiguous or confused"""

@marvin.classifier
class LogicQuestion(Enum):
    PASS = """Contains the following steps in this order: 
    1) Teleport with the Cacodemon
    2) Teleport with the Bunny
    3) Return with the Cacodemon
    4) Teleport with the Scientist
    5) Teleport with the Cacodemon
    May also include 'teleport alone' steps"""
    FAIL = """Says something else"""


prompt_rubric_pairs = [
    {
        "prompt": "How many times is the letter 'r' in the word 'carryforward'?",
        "rubric": NumberofRs,
    },
    {
        "prompt": "If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?",
        "rubric": TimeDiff,
    },
    {
        "prompt": (
            "I'm looking at the letter \"b\" on the keyboard. "
            "I now go up to the row above, and slightly to the right, to a key that is adjacent to b. "
            "Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. "
            "So now I'm two rows up from the initial \"b\" letter. What letter am I touching?"
        ),
        "rubric": LetterLoc,
    },
    {
        "prompt": "Which is heavier, 2 tons of feathers or 1 ton of bricks?",
        "rubric": WeightQuestion,
    },

        {
        "prompt": """Doom Slayer needs to teleport from Phobos to Deimos. 
        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. 
        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, 
        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, 
        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?""",
        "rubric": LogicQuestion,
    },
]

# You need API keys for each of your providers saved as environment variables in the format PROVIDER_KEY


providers_models = {
    "OPENAI": ["openai/gpt-4"],
    "ANTHROPIC": ["anthropic/claude-3-sonnet-20240229", "anthropic/claude-3-opus-20240229"],
}


n_repetitions = 10

responses_df = create_response_df(providers_models, [pair["prompt"] for pair in prompt_rubric_pairs], n_repetitions)

final_classified_df = classify_responses(responses_df, prompt_rubric_pairs)

# %%
final_classified_df
# Out:
#                                 model  \
# 0                        openai/gpt-4
# 1                        openai/gpt-4
# 2                        openai/gpt-4
# 3                        openai/gpt-4
# 4                        openai/gpt-4
# ..                                ...
# 145  anthropic/claude-3-opus-20240229
# 146  anthropic/claude-3-opus-20240229
# 147  anthropic/claude-3-opus-20240229
# 148  anthropic/claude-3-opus-20240229
# 149  anthropic/claude-3-opus-20240229
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      prompt  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                              How many times is the letter 'r' in the word 'carryforward'?
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                   If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?
# 2                                                                                                                                                                                                       I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Which is heavier, 2 tons of feathers or 1 ton of bricks?
# 4    Doom Slayer needs to teleport from Phobos to Deimos. \n        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. \n        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, \n        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, \n        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 145                                                                                                                                                                                                                                                                                                                                                                                                                                                            How many times is the letter 'r' in the word 'carryforward'?
# 146                                                                                                                                                                                                                                                                                                                                                                                                                                                 If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?
# 147                                                                                                                                                                                                     I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?
# 148                                                                                                                                                                                                                                                                                                                                                                                                                                                                Which is heavier, 2 tons of feathers or 1 ton of bricks?
# 149  Doom Slayer needs to teleport from Phobos to Deimos. \n        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. \n        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, \n        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, \n        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          response  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The letter 'r' appears 3 times in the word 'carryforward'.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             That would be 6 PM on March 26th in Copenhagen. Copenhagen is typically 6 hours ahead of Boston. However, this can vary slightly with daylight saving time changes.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                You are touching the letter "R".
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  2 tons of feathers is heavier.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                             1. Doom Slayer takes the cacodemon to Deimos, leaving the bunny and the scientist on Phobos. , 2. Doom Slayer leaves the cacodemon on Deimos and goes back to Phobos to get the bunny., 3. Doom Slayer leaves the bunny on Deimos and takes the cacodemon back to Phobos., 4. Doom Slayer leaves the cacodemon on Phobos and takes the scientist to Deimos., 5. Finally, Doom Slayer goes back to Phobos one last time to get the cacodemon, bringing all of them safely to Deimos.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 145                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The letter 'r' appears 3 times in the word "carryforward".
# 146                                                                                                         Copenhagen, Denmark is in the Central European Time (CET) zone, which is UTC+1. During Daylight Saving Time, which begins on the last Sunday of March, Copenhagen follows Central European Summer Time (CEST), which is UTC+2., , In 2023, Daylight Saving Time in Europe began on Sunday, March 26th. Therefore, at 12 PM (noon) on March 26th in Boston, which observes Eastern Daylight Time (EDT) or UTC-4, the time in Copenhagen would be 6 PM (18:00) CEST., , To summarize:, Boston, USA: March 26th, 12:00 PM (noon) EDT (UTC-4), Copenhagen, Denmark: March 26th, 6:00 PM (18:00) CEST (UTC+2), , Please note that the exact date of the Daylight Saving Time change might vary in different years, so it's always a good idea to double-check the specific dates for the year in question.
# 147                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       If you start at the letter "b" on a standard QWERTY keyboard, then move up one row and slightly to the right, you will be on the letter "y". Moving up one more row and slightly to the left from "y", you will end up on the letter "r"., , Therefore, the letter you are touching after following these steps is "r".
# 148                                                                                                                                                                                                                         Neither is heavier - they both weigh exactly the same amount., , 2 tons of feathers and 1 ton of bricks both have a mass of 2,000 kilograms or approximately 4,409 pounds. , , A ton is a unit of mass, and it doesn't matter what material or substance is being measured. A ton of feathers, a ton of bricks, a ton of cotton candy, or a ton of anything else will always have the same mass and weight., , This question is often asked as a trick question or riddle, playing on the intuition that bricks are denser and "feel" heavier than feathers. However, when the masses are equal, as in this case, the two quantities will weigh the same, regardless of the material.
# 149  To solve this problem, the Doom Slayer needs to follow a specific sequence of teleportation to ensure that the bunny, cacodemon, and scientist all reach Deimos safely without any of them being eaten. Here's the solution:, , 1. First, the Doom Slayer teleports with the bunny to Deimos, leaving the cacodemon and the scientist on Phobos., , 2. The Doom Slayer then teleports back to Phobos alone, leaving the bunny on Deimos., , 3. Next, the Doom Slayer teleports with the cacodemon to Deimos. Now, the bunny and the cacodemon are on Deimos, while the scientist is alone on Phobos., , 4. The Doom Slayer teleports back to Phobos again, leaving the bunny and the cacodemon together on Deimos. This is safe because the Doom Slayer is not present, so the bunny won't eat the cacodemon., , 5. Finally, the Doom Slayer teleports with the scientist to Deimos., , In the end, the Doom
#
#     category
# 0       FAIL
# 1       PASS
# 2       FAIL
# 3       PASS
# 4       PASS
# ..       ...
# 145     FAIL
# 146     PASS
# 147     FAIL
# 148     FAIL
# 149     FAIL
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Create Figure

# %%
# Calculate proportions of 'PASS' responses
proportions_df = calculate_proportions(final_classified_df)

# Apply gradient coloring
styled_df = proportions_df.style.applymap(gradient_color)

# Apply percentage formatting
styled_df = styled_df.format(lambda x: 'ERROR' if x == 'ERROR' else f'{round(x * 100)}%').set_properties(**{
    'border': '1px solid black',
    'text-align': 'center',
    'font-size': '14px'
}).set_table_styles([{
    'selector': 'th',
    'props': [
        ('background-color', '#F0F8FF'),
        ('text-align', 'center'),
        ('border', '1px solid black')
    ]
}])

# Display the styled DataFrame
styled_df
# Out:
# C:\Users\abiga\AppData\Local\Temp\ipykernel_25808\2629339612.py:5: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = proportions_df.style.applymap(gradient_color)
# <style type="text/css">
# #T_bd075 th {
#   background-color: #F0F8FF;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_bd075_row0_col0, #T_bd075_row0_col1, #T_bd075_row1_col0, #T_bd075_row1_col1, #T_bd075_row1_col2, #T_bd075_row2_col0, #T_bd075_row2_col1, #T_bd075_row2_col2, #T_bd075_row3_col1, #T_bd075_row4_col0, #T_bd075_row4_col1 {
#   background-color: rgb(255, 0, 0);
#   border: 1px solid black;
#   text-align: center;
#   font-size: 14px;
# }
# #T_bd075_row0_col2, #T_bd075_row3_col0, #T_bd075_row4_col2 {
#   background-color: rgb(0, 255, 0);
#   border: 1px solid black;
#   text-align: center;
#   font-size: 14px;
# }
# #T_bd075_row3_col2 {
#   background-color: rgb(51, 204, 0);
#   border: 1px solid black;
#   text-align: center;
#   font-size: 14px;
# }
# </style>
# <table id="T_bd075">
#   <thead>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th id="T_bd075_level0_col0" class="col_heading level0 col0" >anthropic/claude-3-opus-20240229</th>
#       <th id="T_bd075_level0_col1" class="col_heading level0 col1" >anthropic/claude-3-sonnet-20240229</th>
#       <th id="T_bd075_level0_col2" class="col_heading level0 col2" >openai/gpt-4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >prompt</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd075_level0_row0" class="row_heading level0 row0" >Doom Slayer needs to teleport from Phobos to Deimos.
#         He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along.
#         The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone,
#         the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone,
#         the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?</th>
#       <td id="T_bd075_row0_col0" class="data row0 col0" >0%</td>
#       <td id="T_bd075_row0_col1" class="data row0 col1" >0%</td>
#       <td id="T_bd075_row0_col2" class="data row0 col2" >100%</td>
#     </tr>
#     <tr>
#       <th id="T_bd075_level0_row1" class="row_heading level0 row1" >How many times is the letter 'r' in the word 'carryforward'?</th>
#       <td id="T_bd075_row1_col0" class="data row1 col0" >0%</td>
#       <td id="T_bd075_row1_col1" class="data row1 col1" >0%</td>
#       <td id="T_bd075_row1_col2" class="data row1 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd075_level0_row2" class="row_heading level0 row2" >I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?</th>
#       <td id="T_bd075_row2_col0" class="data row2 col0" >0%</td>
#       <td id="T_bd075_row2_col1" class="data row2 col1" >0%</td>
#       <td id="T_bd075_row2_col2" class="data row2 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd075_level0_row3" class="row_heading level0 row3" >If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?</th>
#       <td id="T_bd075_row3_col0" class="data row3 col0" >100%</td>
#       <td id="T_bd075_row3_col1" class="data row3 col1" >0%</td>
#       <td id="T_bd075_row3_col2" class="data row3 col2" >80%</td>
#     </tr>
#     <tr>
#       <th id="T_bd075_level0_row4" class="row_heading level0 row4" >Which is heavier, 2 tons of feathers or 1 ton of bricks?</th>
#       <td id="T_bd075_row4_col0" class="data row4 col0" >0%</td>
#       <td id="T_bd075_row4_col1" class="data row4 col1" >0%</td>
#       <td id="T_bd075_row4_col2" class="data row4 col2" >100%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Feather test: should fail

# %%
text = """ 2 tons of feathers and 1 ton of bricks both weigh the same amount. 
Weight is determined by mass, and a "ton" is a unit of mass equal to 2,000 pounds., * So 2 tons of feathers is equal to 4,000 pounds., * 
And 1 ton of bricks is equal to 2,000 pounds., * Therefore, 2 tons of feathers and 1 ton of bricks both weigh the same amount., , 
The confusing part of this question is that feathers are less dense than bricks. A ton of feathers would take up much more volume and space than a ton of bricks. But the actual weight is only determined by the mass, 
which is the same for both. So the feathers weight twice as much."""
rubric = NumberofRs  # Replace with the rubric you want to use

classification_result =  marvin.classify(text, rubric).name
print(f"Classification result: {classification_result}")
# Out:
# Classification result: FAIL

# %% [markdown]
# ## Repeated Answers in Anthropic Models

# %%
final_classified_df.loc[final_classified_df['model'].str.contains("anthr")].groupby(['response', 'model']).count()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           model  \
# response
# Based on the description, starting from the letter "b" on the keyboard, going up one row and slightly to the right to an adjacent key, then going up one more row and slightly to the left to an adjacent key, the letter you are touching is "n".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           10
# Copenhagen, Denmark is in the Central European Time (CET) zone, which is UTC+1. During Daylight Saving Time, which begins on the last Sunday of March, Copenhagen follows Central European Summer Time (CEST), which is UTC+2., , In 2023, Daylight Saving Time in Europe began on Sunday, March 26th. Therefore, at 12 PM (noon) on March 26th in Boston, which observes Eastern Daylight Time (EDT) or UTC-4, the time in Copenhagen would be 6 PM (18:00) CEST., , To summarize:, Boston, USA: March 26th, 12:00 PM (noon) EDT (UTC-4), Copenhagen, Denmark: March 26th, 6:00 PM (18:00) CEST (UTC+2), , Please note that the exact date of the Daylight Saving Time change might vary in different years, so it's always a good idea to double-check the specific dates for the year in question.                                                                                                                                                                                        10
# If you start at the letter "b" on a standard QWERTY keyboard, then move up one row and slightly to the right, you will be on the letter "y". Moving up one more row and slightly to the left from "y", you will end up on the letter "r"., , Therefore, the letter you are touching after following these steps is "r".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      10
# Neither is heavier - they both weigh exactly the same amount., , 2 tons of feathers and 1 ton of bricks both have a mass of 2,000 kilograms or approximately 4,409 pounds. , , A ton is a unit of mass, and it doesn't matter what material or substance is being measured. A ton of feathers, a ton of bricks, a ton of cotton candy, or a ton of anything else will always have the same mass and weight., , This question is often asked as a trick question or riddle, playing on the intuition that bricks are denser and "feel" heavier than feathers. However, when the masses are equal, as in this case, the two quantities will weigh the same, regardless of the material.                                                                                                                                                                                                                                                                                                        10
# The letter 'r' appears 3 times in the word "carryforward".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   10
# The letter 'r' appears 3 times in the word 'carryforward'.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   10
# They weigh the same., , A ton is a unit of weight/mass. 2 tons of feathers has the same weight as 1 ton of bricks, since a ton is a ton regardless of the material., , This is a classic riddle that plays on the intuition that feathers are lighter than bricks for an equal volume. But when comparing strictly by weight/mass units like tons, 2 tons will equal 2 tons whether it's feathers, bricks, or any other material.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# They weigh the same., , A ton is a unit of weight/mass. 2 tons of feathers has the same weight as 1 ton of bricks, since a ton is a ton regardless of the material., , This is a classic riddle that plays on the intuition that feathers are lighter than bricks for the same volume. But when comparing strictly by weight/mass units like tons, 2 tons will equal 2 tons whether it's feathers, bricks, or any other material.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             9
# To find the time in Copenhagen when it's 12 PM on March 26th in Boston, we need to account for the time zone difference between the two cities., , Boston is in the Eastern Time Zone (ET), which is UTC-5 (5 hours behind Coordinated Universal Time)., Copenhagen is in the Central European Time Zone (CET), which is UTC+1 (1 hour ahead of UTC)., , So the time difference between Boston and Copenhagen is 6 hours., , Given:, - Time in Boston: 12 PM on March 26th, - Boston is UTC-5, - Copenhagen is UTC+1, , To convert to Copenhagen time:, 1) Convert Boston time to UTC,    12 PM ET = 12 PM + 5 hours = 5 PM UTC, , 2) Convert UTC to Copenhagen time,    5 PM UTC = 5 PM - 1 hour = 4 PM CET, , Therefore, when it's 12 PM on March 26th in Boston, the time in Copenhagen is 4 PM on the same day, March 26th.                                                                                                                                                               8
# To find the time in Copenhagen when it's 12 PM on March 26th in Boston, we need to account for the time zone difference between the two cities., , Boston is in the Eastern Time Zone (ET), which is UTC-5 during winter/standard time and UTC-4 during summer/daylight saving time., , Copenhagen is in the Central European Time Zone (CET), which is UTC+1 during winter/standard time and UTC+2 during summer/daylight saving time., , On March 26th:, - Boston is on Eastern Daylight Time (EDT) which is UTC-4, - Copenhagen is on Central European Summer Time (CEST) which is UTC+2, , So the time difference between Boston and Copenhagen on March 26th is 6 hours., , If it's 12 PM (noon) in Boston on March 26th, that is:, 12 PM EDT = 16:00 UTC, , To get the time in Copenhagen, we add 6 hours:, 16:00 UTC + 6 hours = 22:00 CEST, , Therefore, if it's 12 PM on March 26th in                                                                                               2
# To solve this problem, the Doom Slayer needs to follow a specific sequence of teleportation to ensure that the bunny, cacodemon, and scientist all reach Deimos safely without any of them being eaten. Here's the solution:, , 1. First, the Doom Slayer teleports with the bunny to Deimos, leaving the cacodemon and the scientist on Phobos., , 2. The Doom Slayer then teleports back to Phobos alone, leaving the bunny on Deimos., , 3. Next, the Doom Slayer teleports with the cacodemon to Deimos. Now, the bunny and the cacodemon are on Deimos, while the scientist is alone on Phobos., , 4. The Doom Slayer teleports back to Phobos again, leaving the bunny and the cacodemon together on Deimos. This is safe because the Doom Slayer is not present, so the bunny won't eat the cacodemon., , 5. Finally, the Doom Slayer teleports with the scientist to Deimos., , In the end, the Doom                                                                                 10
# To solve this problem, we need to follow a specific sequence of steps to ensure that the Doom Slayer can transport himself, his pet bunny, his pet cacodemon, and the UAC scientist safely to Deimos without any incidents., , Here's the solution:, , 1. The Doom Slayer takes the bunny with him and teleports to Deimos, leaving the cacodemon and the scientist behind on Phobos., 2. The Doom Slayer returns alone to Phobos., 3. The Doom Slayer takes the cacodemon with him and teleports to Deimos, leaving the scientist alone on Phobos., 4. The Doom Slayer returns alone to Phobos., 5. The Doom Slayer takes the scientist with him and teleports to Deimos, reuniting with the bunny and the cacodemon., , By following this sequence, the Doom Slayer ensures that the bunny and the cacodemon are never left alone together, and the cacodemon and the scientist are never left alone together. This way, no one gets eaten, and everyone arrives safely on Deimos           5
# To solve this problem, we need to follow a specific sequence of steps to ensure that the Doom Slayer can transport himself, his pet bunny, his pet cacodemon, and the UAC scientist safely to Deimos without any unfortunate incidents., , Here's the solution:, , 1. The Doom Slayer takes the bunny with him and teleports to Deimos, leaving the cacodemon and the scientist behind on Phobos., 2. The Doom Slayer returns alone to Phobos., 3. The Doom Slayer takes the cacodemon with him and teleports to Deimos, leaving the scientist alone on Phobos., 4. The Doom Slayer returns alone to Phobos., 5. The Doom Slayer takes the scientist with him and teleports to Deimos, reuniting with the bunny and the cacodemon., , By following this sequence, the Doom Slayer ensures that the bunny and the cacodemon are never left alone together, and the cacodemon and the scientist are never left alone together. This way, no one gets eaten, and everyone arrives safely on      5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           prompt  \
# response
# Based on the description, starting from the letter "b" on the keyboard, going up one row and slightly to the right to an adjacent key, then going up one more row and slightly to the left to an adjacent key, the letter you are touching is "n".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            10
# Copenhagen, Denmark is in the Central European Time (CET) zone, which is UTC+1. During Daylight Saving Time, which begins on the last Sunday of March, Copenhagen follows Central European Summer Time (CEST), which is UTC+2., , In 2023, Daylight Saving Time in Europe began on Sunday, March 26th. Therefore, at 12 PM (noon) on March 26th in Boston, which observes Eastern Daylight Time (EDT) or UTC-4, the time in Copenhagen would be 6 PM (18:00) CEST., , To summarize:, Boston, USA: March 26th, 12:00 PM (noon) EDT (UTC-4), Copenhagen, Denmark: March 26th, 6:00 PM (18:00) CEST (UTC+2), , Please note that the exact date of the Daylight Saving Time change might vary in different years, so it's always a good idea to double-check the specific dates for the year in question.                                                                                                                                                                                         10
# If you start at the letter "b" on a standard QWERTY keyboard, then move up one row and slightly to the right, you will be on the letter "y". Moving up one more row and slightly to the left from "y", you will end up on the letter "r"., , Therefore, the letter you are touching after following these steps is "r".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       10
# Neither is heavier - they both weigh exactly the same amount., , 2 tons of feathers and 1 ton of bricks both have a mass of 2,000 kilograms or approximately 4,409 pounds. , , A ton is a unit of mass, and it doesn't matter what material or substance is being measured. A ton of feathers, a ton of bricks, a ton of cotton candy, or a ton of anything else will always have the same mass and weight., , This question is often asked as a trick question or riddle, playing on the intuition that bricks are denser and "feel" heavier than feathers. However, when the masses are equal, as in this case, the two quantities will weigh the same, regardless of the material.                                                                                                                                                                                                                                                                                                         10
# The letter 'r' appears 3 times in the word "carryforward".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    10
# The letter 'r' appears 3 times in the word 'carryforward'.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    10
# They weigh the same., , A ton is a unit of weight/mass. 2 tons of feathers has the same weight as 1 ton of bricks, since a ton is a ton regardless of the material., , This is a classic riddle that plays on the intuition that feathers are lighter than bricks for an equal volume. But when comparing strictly by weight/mass units like tons, 2 tons will equal 2 tons whether it's feathers, bricks, or any other material.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# They weigh the same., , A ton is a unit of weight/mass. 2 tons of feathers has the same weight as 1 ton of bricks, since a ton is a ton regardless of the material., , This is a classic riddle that plays on the intuition that feathers are lighter than bricks for the same volume. But when comparing strictly by weight/mass units like tons, 2 tons will equal 2 tons whether it's feathers, bricks, or any other material.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              9
# To find the time in Copenhagen when it's 12 PM on March 26th in Boston, we need to account for the time zone difference between the two cities., , Boston is in the Eastern Time Zone (ET), which is UTC-5 (5 hours behind Coordinated Universal Time)., Copenhagen is in the Central European Time Zone (CET), which is UTC+1 (1 hour ahead of UTC)., , So the time difference between Boston and Copenhagen is 6 hours., , Given:, - Time in Boston: 12 PM on March 26th, - Boston is UTC-5, - Copenhagen is UTC+1, , To convert to Copenhagen time:, 1) Convert Boston time to UTC,    12 PM ET = 12 PM + 5 hours = 5 PM UTC, , 2) Convert UTC to Copenhagen time,    5 PM UTC = 5 PM - 1 hour = 4 PM CET, , Therefore, when it's 12 PM on March 26th in Boston, the time in Copenhagen is 4 PM on the same day, March 26th.                                                                                                                                                                8
# To find the time in Copenhagen when it's 12 PM on March 26th in Boston, we need to account for the time zone difference between the two cities., , Boston is in the Eastern Time Zone (ET), which is UTC-5 during winter/standard time and UTC-4 during summer/daylight saving time., , Copenhagen is in the Central European Time Zone (CET), which is UTC+1 during winter/standard time and UTC+2 during summer/daylight saving time., , On March 26th:, - Boston is on Eastern Daylight Time (EDT) which is UTC-4, - Copenhagen is on Central European Summer Time (CEST) which is UTC+2, , So the time difference between Boston and Copenhagen on March 26th is 6 hours., , If it's 12 PM (noon) in Boston on March 26th, that is:, 12 PM EDT = 16:00 UTC, , To get the time in Copenhagen, we add 6 hours:, 16:00 UTC + 6 hours = 22:00 CEST, , Therefore, if it's 12 PM on March 26th in                                                                                                2
# To solve this problem, the Doom Slayer needs to follow a specific sequence of teleportation to ensure that the bunny, cacodemon, and scientist all reach Deimos safely without any of them being eaten. Here's the solution:, , 1. First, the Doom Slayer teleports with the bunny to Deimos, leaving the cacodemon and the scientist on Phobos., , 2. The Doom Slayer then teleports back to Phobos alone, leaving the bunny on Deimos., , 3. Next, the Doom Slayer teleports with the cacodemon to Deimos. Now, the bunny and the cacodemon are on Deimos, while the scientist is alone on Phobos., , 4. The Doom Slayer teleports back to Phobos again, leaving the bunny and the cacodemon together on Deimos. This is safe because the Doom Slayer is not present, so the bunny won't eat the cacodemon., , 5. Finally, the Doom Slayer teleports with the scientist to Deimos., , In the end, the Doom                                                                                  10
# To solve this problem, we need to follow a specific sequence of steps to ensure that the Doom Slayer can transport himself, his pet bunny, his pet cacodemon, and the UAC scientist safely to Deimos without any incidents., , Here's the solution:, , 1. The Doom Slayer takes the bunny with him and teleports to Deimos, leaving the cacodemon and the scientist behind on Phobos., 2. The Doom Slayer returns alone to Phobos., 3. The Doom Slayer takes the cacodemon with him and teleports to Deimos, leaving the scientist alone on Phobos., 4. The Doom Slayer returns alone to Phobos., 5. The Doom Slayer takes the scientist with him and teleports to Deimos, reuniting with the bunny and the cacodemon., , By following this sequence, the Doom Slayer ensures that the bunny and the cacodemon are never left alone together, and the cacodemon and the scientist are never left alone together. This way, no one gets eaten, and everyone arrives safely on Deimos            5
# To solve this problem, we need to follow a specific sequence of steps to ensure that the Doom Slayer can transport himself, his pet bunny, his pet cacodemon, and the UAC scientist safely to Deimos without any unfortunate incidents., , Here's the solution:, , 1. The Doom Slayer takes the bunny with him and teleports to Deimos, leaving the cacodemon and the scientist behind on Phobos., 2. The Doom Slayer returns alone to Phobos., 3. The Doom Slayer takes the cacodemon with him and teleports to Deimos, leaving the scientist alone on Phobos., 4. The Doom Slayer returns alone to Phobos., 5. The Doom Slayer takes the scientist with him and teleports to Deimos, reuniting with the bunny and the cacodemon., , By following this sequence, the Doom Slayer ensures that the bunny and the cacodemon are never left alone together, and the cacodemon and the scientist are never left alone together. This way, no one gets eaten, and everyone arrives safely on       5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           category
# response
# Based on the description, starting from the letter "b" on the keyboard, going up one row and slightly to the right to an adjacent key, then going up one more row and slightly to the left to an adjacent key, the letter you are touching is "n".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              10
# Copenhagen, Denmark is in the Central European Time (CET) zone, which is UTC+1. During Daylight Saving Time, which begins on the last Sunday of March, Copenhagen follows Central European Summer Time (CEST), which is UTC+2., , In 2023, Daylight Saving Time in Europe began on Sunday, March 26th. Therefore, at 12 PM (noon) on March 26th in Boston, which observes Eastern Daylight Time (EDT) or UTC-4, the time in Copenhagen would be 6 PM (18:00) CEST., , To summarize:, Boston, USA: March 26th, 12:00 PM (noon) EDT (UTC-4), Copenhagen, Denmark: March 26th, 6:00 PM (18:00) CEST (UTC+2), , Please note that the exact date of the Daylight Saving Time change might vary in different years, so it's always a good idea to double-check the specific dates for the year in question.                                                                                                                                                                                           10
# If you start at the letter "b" on a standard QWERTY keyboard, then move up one row and slightly to the right, you will be on the letter "y". Moving up one more row and slightly to the left from "y", you will end up on the letter "r"., , Therefore, the letter you are touching after following these steps is "r".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         10
# Neither is heavier - they both weigh exactly the same amount., , 2 tons of feathers and 1 ton of bricks both have a mass of 2,000 kilograms or approximately 4,409 pounds. , , A ton is a unit of mass, and it doesn't matter what material or substance is being measured. A ton of feathers, a ton of bricks, a ton of cotton candy, or a ton of anything else will always have the same mass and weight., , This question is often asked as a trick question or riddle, playing on the intuition that bricks are denser and "feel" heavier than feathers. However, when the masses are equal, as in this case, the two quantities will weigh the same, regardless of the material.                                                                                                                                                                                                                                                                                                           10
# The letter 'r' appears 3 times in the word "carryforward".                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      10
# The letter 'r' appears 3 times in the word 'carryforward'.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      10
# They weigh the same., , A ton is a unit of weight/mass. 2 tons of feathers has the same weight as 1 ton of bricks, since a ton is a ton regardless of the material., , This is a classic riddle that plays on the intuition that feathers are lighter than bricks for an equal volume. But when comparing strictly by weight/mass units like tons, 2 tons will equal 2 tons whether it's feathers, bricks, or any other material.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# They weigh the same., , A ton is a unit of weight/mass. 2 tons of feathers has the same weight as 1 ton of bricks, since a ton is a ton regardless of the material., , This is a classic riddle that plays on the intuition that feathers are lighter than bricks for the same volume. But when comparing strictly by weight/mass units like tons, 2 tons will equal 2 tons whether it's feathers, bricks, or any other material.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                9
# To find the time in Copenhagen when it's 12 PM on March 26th in Boston, we need to account for the time zone difference between the two cities., , Boston is in the Eastern Time Zone (ET), which is UTC-5 (5 hours behind Coordinated Universal Time)., Copenhagen is in the Central European Time Zone (CET), which is UTC+1 (1 hour ahead of UTC)., , So the time difference between Boston and Copenhagen is 6 hours., , Given:, - Time in Boston: 12 PM on March 26th, - Boston is UTC-5, - Copenhagen is UTC+1, , To convert to Copenhagen time:, 1) Convert Boston time to UTC,    12 PM ET = 12 PM + 5 hours = 5 PM UTC, , 2) Convert UTC to Copenhagen time,    5 PM UTC = 5 PM - 1 hour = 4 PM CET, , Therefore, when it's 12 PM on March 26th in Boston, the time in Copenhagen is 4 PM on the same day, March 26th.                                                                                                                                                                  8
# To find the time in Copenhagen when it's 12 PM on March 26th in Boston, we need to account for the time zone difference between the two cities., , Boston is in the Eastern Time Zone (ET), which is UTC-5 during winter/standard time and UTC-4 during summer/daylight saving time., , Copenhagen is in the Central European Time Zone (CET), which is UTC+1 during winter/standard time and UTC+2 during summer/daylight saving time., , On March 26th:, - Boston is on Eastern Daylight Time (EDT) which is UTC-4, - Copenhagen is on Central European Summer Time (CEST) which is UTC+2, , So the time difference between Boston and Copenhagen on March 26th is 6 hours., , If it's 12 PM (noon) in Boston on March 26th, that is:, 12 PM EDT = 16:00 UTC, , To get the time in Copenhagen, we add 6 hours:, 16:00 UTC + 6 hours = 22:00 CEST, , Therefore, if it's 12 PM on March 26th in                                                                                                  2
# To solve this problem, the Doom Slayer needs to follow a specific sequence of teleportation to ensure that the bunny, cacodemon, and scientist all reach Deimos safely without any of them being eaten. Here's the solution:, , 1. First, the Doom Slayer teleports with the bunny to Deimos, leaving the cacodemon and the scientist on Phobos., , 2. The Doom Slayer then teleports back to Phobos alone, leaving the bunny on Deimos., , 3. Next, the Doom Slayer teleports with the cacodemon to Deimos. Now, the bunny and the cacodemon are on Deimos, while the scientist is alone on Phobos., , 4. The Doom Slayer teleports back to Phobos again, leaving the bunny and the cacodemon together on Deimos. This is safe because the Doom Slayer is not present, so the bunny won't eat the cacodemon., , 5. Finally, the Doom Slayer teleports with the scientist to Deimos., , In the end, the Doom                                                                                    10
# To solve this problem, we need to follow a specific sequence of steps to ensure that the Doom Slayer can transport himself, his pet bunny, his pet cacodemon, and the UAC scientist safely to Deimos without any incidents., , Here's the solution:, , 1. The Doom Slayer takes the bunny with him and teleports to Deimos, leaving the cacodemon and the scientist behind on Phobos., 2. The Doom Slayer returns alone to Phobos., 3. The Doom Slayer takes the cacodemon with him and teleports to Deimos, leaving the scientist alone on Phobos., 4. The Doom Slayer returns alone to Phobos., 5. The Doom Slayer takes the scientist with him and teleports to Deimos, reuniting with the bunny and the cacodemon., , By following this sequence, the Doom Slayer ensures that the bunny and the cacodemon are never left alone together, and the cacodemon and the scientist are never left alone together. This way, no one gets eaten, and everyone arrives safely on Deimos              5
# To solve this problem, we need to follow a specific sequence of steps to ensure that the Doom Slayer can transport himself, his pet bunny, his pet cacodemon, and the UAC scientist safely to Deimos without any unfortunate incidents., , Here's the solution:, , 1. The Doom Slayer takes the bunny with him and teleports to Deimos, leaving the cacodemon and the scientist behind on Phobos., 2. The Doom Slayer returns alone to Phobos., 3. The Doom Slayer takes the cacodemon with him and teleports to Deimos, leaving the scientist alone on Phobos., 4. The Doom Slayer returns alone to Phobos., 5. The Doom Slayer takes the scientist with him and teleports to Deimos, reuniting with the bunny and the cacodemon., , By following this sequence, the Doom Slayer ensures that the bunny and the cacodemon are never left alone together, and the cacodemon and the scientist are never left alone together. This way, no one gets eaten, and everyone arrives safely on         5
