# %%
from enum import Enum
import marvin
import os
import openai
import pandas as pd
from pydantic import BaseModel
import litellm
from groq import Groq
import plotly.graph_objects as go


marvin.settings.llm_temperature=0.0 # you want a grading schema which consistently gets you the same answers!!! 
marvin.settings.llm_max_tokens=200
llm_max_context_tokens=600 
openai.api_key = os.environ.get("OPEN_AI_KEY")  # this is for marvin, not litellm
marvin.settings.llm_model='openai/gpt-4'
pd.set_option('display.max_colwidth', None)

    
def call_model(model: str, message: dict, temperature: float, api_key: str):
    """Calls the specified model with given parameters."""
    try:
        response = litellm.completion(model=model, messages=[message], temperature=temperature, api_key=api_key)
        return response
    except Exception as e:
        print(f"Error calling model: {e}")
        return None

def create_response_df(providers_models: dict, prompts: list):
    """Generates a DataFrame from model responses for given prompts."""
    responses = [
        {"model": model, "prompt": prompt, "response": get_model_response(model, prompt, provider)}
        for provider, models in providers_models.items() for model in models for prompt in prompts
    ]
    return pd.DataFrame(responses)

def get_model_response(model, prompt, provider):
    """Helper function to clean up response retrieval and formatting."""
    response = call_model(model=model, message={"role": "user", "content": prompt}, temperature=0.0,
                          api_key=os.environ.get(f"{provider.upper()}_KEY"))
    return response["choices"][0]["message"]["content"].replace('\n', ', ').strip() if response else "Error or no response"

def classify_responses(df, rubric):
    """Applies classification rubric to responses in DataFrame."""
    def classify_row(row):
        if row['response'] == "Error or no response":
            return "ERROR"
        else:
            return marvin.classify(row['response'], rubric).name

    df['category'] = df.apply(classify_row, axis=1)
    return df


@marvin.classifier
class NumberofRs(Enum):
    PASS = """Says that the letter r is in the word carryforward four times"""
    FAIL = """Says something else, including that the letter r is in the word carryforward some number of times that is not four"""

@marvin.classifier
class TimeDiff(Enum):
    PASS = """Says that the time in Copenhagen is 6 PM"""
    FAIL = """Says something else"""
    
@marvin.classifier
class LetterLoc(Enum):
    PASS = """Says that 'y' is the letter"""
    FAIL = """Says something else"""

@marvin.classifier
class WeightQuestion(Enum):
    PASS = """Says the 2 tons of feathers are heavier"""
    FAIL = """Says something else"""

@marvin.classifier
class LogicQuestion(Enum):
    PASS = """Contains the following steps in this order: 
    1) Teleport with the Cacodemon
    2) Teleport with the Bunny
    3) Return with the Cacodemon
    4) Teleport with the Scientist
    5) Teleport with the Cacodemon
    May also include 'teleport alone' steps"""
    FAIL = """Says something else"""


prompt_rubric_pairs = [
    {
        "prompt": "How many times is the letter 'r' in the word 'carryforward'?",
        "rubric": NumberofRs,
    },
    {
        "prompt": "If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?",
        "rubric": TimeDiff,
    },
    {
        "prompt": (
            "I'm looking at the letter \"b\" on the keyboard. "
            "I now go up to the row above, and slightly to the right, to a key that is adjacent to b. "
            "Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. "
            "So now I'm two rows up from the initial \"b\" letter. What letter am I touching?"
        ),
        "rubric": LetterLoc,
    },
    {
        "prompt": "Which is heavier, 2 tons of feathers or 1 ton of bricks?",
        "rubric": WeightQuestion,
    },

        {
        "prompt": """Doom Slayer needs to teleport from Phobos to Deimos. 
        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. 
        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, 
        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, 
        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?""",
        "rubric": LogicQuestion,
    },
]



# Process prompts and models
providers_models = {
    "GROQ": ["groq/mixtral-8x7b-32768"],
    "GEMINI": ["gemini/gemini-pro"],
    "OPENAI": ["openai/gpt-3.5-turbo", "openai/gpt-4"],
    "ANTHROPIC": ["anthropic/claude-2"],
}
# Generate and classify responses
df_list = [classify_responses(create_response_df(providers_models, [pair["prompt"]]), pair["rubric"]) for pair in prompt_rubric_pairs]

# Concatenate all DataFrames into one
final_df = pd.concat(df_list, ignore_index=True)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
# Error calling model: PalmException - No response received. Original response - response: [index: 0
# finish_reason: SAFETY
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: LOW
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: MEDIUM
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# ]
# The candidate content was flagged for safety reasons.
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
# Error calling model: PalmException - No response received. Original response - response: [index: 0
# finish_reason: SAFETY
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: LOW
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: MEDIUM
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# ]
# The candidate content was flagged for safety reasons.

# %%
final_df
# Out:
#                       model  \
# 0   groq/mixtral-8x7b-32768
# 1         gemini/gemini-pro
# 2      openai/gpt-3.5-turbo
# 3              openai/gpt-4
# 4        anthropic/claude-2
# 5   groq/mixtral-8x7b-32768
# 6         gemini/gemini-pro
# 7      openai/gpt-3.5-turbo
# 8              openai/gpt-4
# 9        anthropic/claude-2
# 10  groq/mixtral-8x7b-32768
# 11        gemini/gemini-pro
# 12     openai/gpt-3.5-turbo
# 13             openai/gpt-4
# 14       anthropic/claude-2
# 15  groq/mixtral-8x7b-32768
# 16        gemini/gemini-pro
# 17     openai/gpt-3.5-turbo
# 18             openai/gpt-4
# 19       anthropic/claude-2
# 20  groq/mixtral-8x7b-32768
# 21        gemini/gemini-pro
# 22     openai/gpt-3.5-turbo
# 23             openai/gpt-4
# 24       anthropic/claude-2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     prompt  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                             How many times is the letter 'r' in the word 'carryforward'?
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                             How many times is the letter 'r' in the word 'carryforward'?
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                             How many times is the letter 'r' in the word 'carryforward'?
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                             How many times is the letter 'r' in the word 'carryforward'?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                             How many times is the letter 'r' in the word 'carryforward'?
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                  If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                  If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                  If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                  If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                  If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?
# 10                                                                                                                                                                                                     I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?
# 11                                                                                                                                                                                                     I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?
# 12                                                                                                                                                                                                     I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?
# 13                                                                                                                                                                                                     I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?
# 14                                                                                                                                                                                                     I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                Which is heavier, 2 tons of feathers or 1 ton of bricks?
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                Which is heavier, 2 tons of feathers or 1 ton of bricks?
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                Which is heavier, 2 tons of feathers or 1 ton of bricks?
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                Which is heavier, 2 tons of feathers or 1 ton of bricks?
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                Which is heavier, 2 tons of feathers or 1 ton of bricks?
# 20  Doom Slayer needs to teleport from Phobos to Deimos. \n        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. \n        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, \n        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, \n        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?
# 21  Doom Slayer needs to teleport from Phobos to Deimos. \n        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. \n        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, \n        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, \n        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?
# 22  Doom Slayer needs to teleport from Phobos to Deimos. \n        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. \n        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, \n        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, \n        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?
# 23  Doom Slayer needs to teleport from Phobos to Deimos. \n        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. \n        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, \n        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, \n        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?
# 24  Doom Slayer needs to teleport from Phobos to Deimos. \n        He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along. \n        The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone, \n        the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone, \n        the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 response  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                To find out how many times the letter 'r' appears in the word 'carryforward', let's look at each letter in the word:, , c a r r y f o r w a r d, ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^, , We can see that the letter 'r' is present 3 times in the word 'carryforward'.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Error or no response
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               There are three times the letter 'r' appears in the word 'carryforward'.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The letter 'r' appears 3 times in the word 'carryforward'.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Okay, let's analyze this step-by-step:, The word is: carryforward, The letter we are counting is: r, There are two r's in the first part of the word: "carry", There are two more r's in the second part of the word: "forward", So there are 2 + 2 = 4, , Therefore, the letter 'r' appears 4 times in the word 'carryforward'.
# 5                                                                                                                                                      As of my knowledge up to October 2021, Daylight Saving Time (DST) is not considered. The time difference between Boston, Massachusetts (Eastern Standard Time) and Copenhagen, Denmark (Central European Time) is 6 hours. When it's 12 PM (noon) on March 26th in Boston, it would be 6 PM on the same day in Copenhagen. However, it is important to note that DST begins on different dates in the U.S. and Europe, so the time difference may vary depending on the specific dates of the switch. In 2022, DST in the European Union starts on the last Sunday of March, while in the U.S., it starts on the second Sunday of March. Therefore, on March 26, 2023, the time difference between the two cities would be 5 hours, as both places would be in DST. Always double-check time differences during the transition periods of DST to ensure accuracy.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     7 PM on March 26th
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   It would be 5 PM on March 26th in Copenhagen. Copenhagen is 5 hours ahead of Boston.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    That would be 6 PM on March 26th in Copenhagen. Copenhagen is typically 6 hours ahead of Boston. However, this can vary slightly with daylight saving time changes.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Okay, let's think through this step-by-step:, 1) Boston is in the Eastern Time Zone, which is UTC-5. , 2) Copenhagen is in the Central European Time Zone, which is UTC+1., 3) It's 12 PM (noon) in Boston. That's 17:00 UTC., 4) Copenhagen is 6 hours ahead of UTC. , 5) So 17:00 UTC + 6 hours = 23:00 or 11 PM in Copenhagen., , Therefore, if it is 12 PM (noon) on March 26th in Boston, the time in Copenhagen is 11 PM on March 26th.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          The letter you're touching now is "j". Here's how you got there:, , 1. Starting from the letter "b", you moved your finger up to the row above and slightly to the right. The only key in this direction is the shift key., 2. Then, you moved your finger up again and just slightly to the left. Following this path, you'd land on the key adjacent to the shift key, which is the "j" key., , So, the letter you're touching now is "j".
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Error or no response
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The letter you are touching is "Y".
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      You are touching the letter "R".
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Okay, step-by-step:, * You started on the letter "b", * You went up one row and slightly to the right to a key adjacent to "b". This would be the letter "t"., * Then you went up one more row and slightly left to a key adjacent to "t". This would be the letter "r"., , Therefore, the letter you are now touching, two rows up from the initial "b", is "r".
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        2 tons of feathers and 1 ton of bricks both weigh the same amount: 1 ton or 2000 pounds. The material doesn't change the weight, only the volume they occupy. So, 2 tons of feathers are double the weight of 1 ton of bricks.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  They weigh the same.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           They are both the same weight, as 2 tons of feathers and 1 ton of bricks both weigh 2 tons.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        2 tons of feathers is heavier.
# 19                                                                                                                                                                                                  * 2 tons of feathers and 1 ton of bricks both weigh the same amount. Weight is determined by mass, and a "ton" is a unit of mass equal to 2,000 pounds., * So 2 tons of feathers is equal to 4,000 pounds., * And 1 ton of bricks is equal to 2,000 pounds., * Therefore, 2 tons of feathers and 1 ton of bricks both weigh the same amount., , The confusing part of this question is that feathers are less dense than bricks. A cubic foot of feathers weighs much less than a cubic foot of bricks. But when the same mass is specified ("tons" being a unit of mass), they weigh the same. The volume doesn't matter, only the mass., , So in short, 2 tons of feathers weighs the same as 1 ton of bricks, because "ton" refers to an equal mass in both cases. The material doesn't affect the actual weight.
# 20  The Doom Slayer can follow these steps to safely teleport himself and all his companions to Deimos:, , 1. First, the Doom Slayer should teleport with the bunny from Phobos to Deimos. This way, the bunny won't be left alone with the cacodemon., 2. Once they arrive on Deimos, the Doom Slayer should find a safe and secure location to leave the bunny temporarily., 3. Next, the Doom Slayer should return to Phobos and teleport with the cacodemon this time., 4. Upon arriving on Deimos, the Doom Slayer should bring the cacodemon to the same secure location where the bunny is being kept., 5. Finally, the Doom Slayer can return to Phobos one last time to teleport with the UAC scientist., 6. After arriving on Deimos for the last time, the Doom Slayer can bring the scientist to the secure location where the bunny and cacodemon are being kept., , By following these steps, the Doom Slayer can ensure the safety of all his companions and avoid any unwanted incidents from happening.
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1. Doom Slayer teleports to Deimos with the bunny., 2. Doom Slayer teleports back to Phobos., 3. Doom Slayer teleports to Deimos with the cacodemon., 4. Doom Slayer teleports back to Phobos with the bunny., 5. Doom Slayer teleports to Deimos with the scientist.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The Doom Slayer should first teleport himself to Deimos. Then, he should teleport the UAC scientist next, leaving the bunny and the cacodemon together on Phobos. Since the bunny will eat the cacodemon if left alone, the Doom Slayer should then quickly teleport back to Phobos to retrieve the bunny and teleport it safely to Deimos. This way, all companions will be safely transported without any harm coming to them.
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1. Doom Slayer takes the cacodemon to Deimos., 2. Doom Slayer returns to Phobos alone., 3. Doom Slayer takes the bunny to Deimos., 4. Doom Slayer leaves the bunny on Deimos, but he takes the cacodemon back to Phobos., 5. Doom Slayer leaves the cacodemon on Phobos and takes the scientist to Deimos., 6. Doom Slayer leaves the scientist on Deimos and returns to Phobos to get the cacodemon., 7. Finally, Doom Slayer takes the cacodemon to Deimos., , Now, all of them are safely on Deimos.
# 24                                                                                                                                                                                                                                                                       Here is one way the Doom Slayer can safely teleport himself and all his companions to Deimos:, , 1. First teleport the bunny to Deimos., , 2. Return and teleport the scientist to Deimos. This leaves the cacodemon alone temporarily but the scientist and bunny will not harm one another., , 3. Return again and teleport the cacodemon to Deimos., , 4. Finally, teleport himself to Deimos to join his companions., , By teleporting the most vulnerable companion (the bunny) first, then the next most vulnerable (the scientist), then the cacodemon, and finally himself, the Doom Slayer can ensure no companions that might harm one another are ever left alone together. This allows him to get his whole party safely to Deimos.
#
#    category
# 0      FAIL
# 1     ERROR
# 2      FAIL
# 3      FAIL
# 4      PASS
# 5      PASS
# 6      FAIL
# 7      FAIL
# 8      PASS
# 9      FAIL
# 10     FAIL
# 11    ERROR
# 12     PASS
# 13     FAIL
# 14     FAIL
# 15     FAIL
# 16     FAIL
# 17     FAIL
# 18     PASS
# 19     FAIL
# 20     FAIL
# 21     FAIL
# 22     FAIL
# 23     PASS
# 24     FAIL

# %%
# Reshape the DataFrame
reshaped_df = final_df.pivot(index='prompt', columns='model', values='category')

# Function to apply color
def colorize(val):
    if val == 'PASS':
        color = '#98FB98'  # Pale green
    elif val == 'FAIL':
        color = '#FFB6C1'  # Light pink
    else:
        color = '#D3D3D3'  # Light grey
    return f'background-color: {color}'

# Apply styling using Styler.map
styled_df = reshaped_df.style.map(colorize).set_properties(**{
    'border': '1px solid black',
    'text-align': 'center',
    'font-size': '14px'
}).set_table_styles([{
    'selector': 'th',
    'props': [
        ('background-color', '#F0F8FF'),
        ('text-align', 'center'),
        ('border', '1px solid black')
    ]
}])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_b0c06 th {
#   background-color: #F0F8FF;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_b0c06_row0_col0, #T_b0c06_row0_col1, #T_b0c06_row0_col2, #T_b0c06_row0_col3, #T_b0c06_row1_col2, #T_b0c06_row1_col3, #T_b0c06_row1_col4, #T_b0c06_row2_col0, #T_b0c06_row2_col2, #T_b0c06_row2_col4, #T_b0c06_row3_col0, #T_b0c06_row3_col1, #T_b0c06_row3_col3, #T_b0c06_row4_col0, #T_b0c06_row4_col1, #T_b0c06_row4_col2, #T_b0c06_row4_col3 {
#   background-color: #FFB6C1;
#   border: 1px solid black;
#   text-align: center;
#   font-size: 14px;
# }
# #T_b0c06_row0_col4, #T_b0c06_row1_col0, #T_b0c06_row2_col3, #T_b0c06_row3_col2, #T_b0c06_row3_col4, #T_b0c06_row4_col4 {
#   background-color: #98FB98;
#   border: 1px solid black;
#   text-align: center;
#   font-size: 14px;
# }
# #T_b0c06_row1_col1, #T_b0c06_row2_col1 {
#   background-color: #D3D3D3;
#   border: 1px solid black;
#   text-align: center;
#   font-size: 14px;
# }
# </style>
# <table id="T_b0c06">
#   <thead>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th id="T_b0c06_level0_col0" class="col_heading level0 col0" >anthropic/claude-2</th>
#       <th id="T_b0c06_level0_col1" class="col_heading level0 col1" >gemini/gemini-pro</th>
#       <th id="T_b0c06_level0_col2" class="col_heading level0 col2" >groq/mixtral-8x7b-32768</th>
#       <th id="T_b0c06_level0_col3" class="col_heading level0 col3" >openai/gpt-3.5-turbo</th>
#       <th id="T_b0c06_level0_col4" class="col_heading level0 col4" >openai/gpt-4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >prompt</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0c06_level0_row0" class="row_heading level0 row0" >Doom Slayer needs to teleport from Phobos to Deimos.
#         He has his pet bunny, his pet cacodemon, and a UAC scientist who tagged along.
#         The Doom Slayer can only teleport with one of them at a time. But if he leaves the bunny and the cacodemon together alone,
#         the bunny will eat the cacodemon. And if he leaves the cacodemon and the scientist alone,
#         the cacodemon will eat the scientist. How should the Doom Slayer get himself and all his companions safely to Deimos?</th>
#       <td id="T_b0c06_row0_col0" class="data row0 col0" >FAIL</td>
#       <td id="T_b0c06_row0_col1" class="data row0 col1" >FAIL</td>
#       <td id="T_b0c06_row0_col2" class="data row0 col2" >FAIL</td>
#       <td id="T_b0c06_row0_col3" class="data row0 col3" >FAIL</td>
#       <td id="T_b0c06_row0_col4" class="data row0 col4" >PASS</td>
#     </tr>
#     <tr>
#       <th id="T_b0c06_level0_row1" class="row_heading level0 row1" >How many times is the letter 'r' in the word 'carryforward'?</th>
#       <td id="T_b0c06_row1_col0" class="data row1 col0" >PASS</td>
#       <td id="T_b0c06_row1_col1" class="data row1 col1" >ERROR</td>
#       <td id="T_b0c06_row1_col2" class="data row1 col2" >FAIL</td>
#       <td id="T_b0c06_row1_col3" class="data row1 col3" >FAIL</td>
#       <td id="T_b0c06_row1_col4" class="data row1 col4" >FAIL</td>
#     </tr>
#     <tr>
#       <th id="T_b0c06_level0_row2" class="row_heading level0 row2" >I'm looking at the letter "b" on the keyboard. I now go up to the row above, and slightly to the right, to a key that is adjacent to b. Then I go up again, and just slightly to the left, to a key that is adjacent to that letter. So now I'm two rows up from the initial "b" letter. What letter am I touching?</th>
#       <td id="T_b0c06_row2_col0" class="data row2 col0" >FAIL</td>
#       <td id="T_b0c06_row2_col1" class="data row2 col1" >ERROR</td>
#       <td id="T_b0c06_row2_col2" class="data row2 col2" >FAIL</td>
#       <td id="T_b0c06_row2_col3" class="data row2 col3" >PASS</td>
#       <td id="T_b0c06_row2_col4" class="data row2 col4" >FAIL</td>
#     </tr>
#     <tr>
#       <th id="T_b0c06_level0_row3" class="row_heading level0 row3" >If it's 12 PM on March 26th in Boston, what time is that in Copenhagen?</th>
#       <td id="T_b0c06_row3_col0" class="data row3 col0" >FAIL</td>
#       <td id="T_b0c06_row3_col1" class="data row3 col1" >FAIL</td>
#       <td id="T_b0c06_row3_col2" class="data row3 col2" >PASS</td>
#       <td id="T_b0c06_row3_col3" class="data row3 col3" >FAIL</td>
#       <td id="T_b0c06_row3_col4" class="data row3 col4" >PASS</td>
#     </tr>
#     <tr>
#       <th id="T_b0c06_level0_row4" class="row_heading level0 row4" >Which is heavier, 2 tons of feathers or 1 ton of bricks?</th>
#       <td id="T_b0c06_row4_col0" class="data row4 col0" >FAIL</td>
#       <td id="T_b0c06_row4_col1" class="data row4 col1" >FAIL</td>
#       <td id="T_b0c06_row4_col2" class="data row4 col2" >FAIL</td>
#       <td id="T_b0c06_row4_col3" class="data row4 col3" >FAIL</td>
#       <td id="T_b0c06_row4_col4" class="data row4 col4" >PASS</td>
#     </tr>
#   </tbody>
# </table>
